# %% [markdown]
# <a href="https://colab.research.google.com/github/M-Abbi/Financial-Modeling/blob/main/Binomail_to_Normal_Distribution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import scipy as sp
import scipy.special as sps
import matplotlib.pyplot as plt

# %%
n = 30
p = 0.5
q = 1-p

# Create Binomial Distribution

PXbinomial =[]
for k in range(n+1):
  probX = sps.comb(n,k) * p**k * q**(n-k)
  PXbinomial.append(probX)

# Create Normal Distribution
mu = n*p
sigma = np.sqrt(n*p*q)

X = np.arange(0,n,0.01)
PXnormal = (1/(sigma*np.sqrt(2*np.pi))) * np.exp(-(X-mu)**2/(2*sigma**2))

#Plot
plt.plot(PXbinomial, label = 'Binomial')
plt.plot(X, PXnormal, label = 'Normal')
plt.legend()
plt.xlim(0,n)
# Out:
# (0.0, 30.0)
